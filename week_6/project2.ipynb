# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage1(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("admitted")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Welcome to Computer Science Department")
    label_2.pack()

    # Run the Tkinter event loop
    window.mainloop()
def welcomeMessage2(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Admitted")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Welcome to Mass Communication Department")
    label_2.pack()

def welcomeMessage3(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Not Admitted")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Sorry but you did not meet up to the requirements")
    label_2.pack()

    # Run the Tkinter event loop
    window.mainloop()
def submit():
    username = username_entry.get()
    jamb = int(jamb_entry.get())
    credits = int(credits_entry.get())
    interview = interview_entry.get()
    department = department_entry.get()
    
    if jamb >=250 and credits>= 5 and interview == "yes" and department == "Computer Science Department":
         welcomeMessage1(username)
    elif jamb >=230 and credits>= 5 and interview == "yes" and department == "Mass Communication Department":
         welcomeMessage2(username)
    else:
        welcomeMessage3(username)
        

   

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x300")

# Create username label and entry
username_label = tk.Label(root, text="Username: ")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

jamb_label = tk.Label(root, text="jamb: ")
jamb_label.pack()
jamb_entry = tk.Entry(root)
jamb_entry.pack()

# Create password label and entry
credits_label = tk.Label(root, text="credits: ")
credits_label.pack()
credits_entry = tk.Entry(root)
credits_entry.pack()

interview_label = tk.Label(root, text="interview: ")
interview_label.pack()
interview_entry = tk.Entry(root)
interview_entry.pack()

# Create password label and entry
department_label = tk.Label(root, text="department: ")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()
# Create submit button

submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
