# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage1(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Simi Services")
    window.geometry("500x200")
    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text=f"Your total fee is 5000")
    label_2.pack()
    # Run the Tkinter event loop
    window.mainloop()

def welcomeMessage2(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Simi Services")
    window.geometry("500x200")
    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text=f"Your total fee is 3500")
    label_2.pack()
     # Run the Tkinter event loop
    window.mainloop()

def welcomeMessage3(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Simi Services")
    window.geometry("500x200")
    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text=f"Your total fee is 10000")
    label_2.pack()
    # Run the Tkinter event loop
    window.mainloop()

def welcomeMessage4(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Simi Services")
    window.geometry("500x200")
    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text=f"Your total fee is 5000")
    label_2.pack()
    # Run the Tkinter event loop
    window.mainloop()

def submit():
    username = username_entry.get()
    destination = destination_entry.get()
    weight = int(weight_entry.get())
    
    if weight   >=10 and destination == "Ibeju-Lekki":
         welcomeMessage1(username)
    elif weight <10 and destination == "Ibeju-Lekki":
        welcomeMessage2(username)
    elif weight >=10 and destination == "Epe":
         welcomeMessage3(username)
    elif weight <=10 and destination == "Epe":
    	welcomeMessage4(username)
    else:
        messagebox.showerror("login","Sorry we do not deliver to this state")

    
# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")

# Create username label and entry
username_label = tk.Label(root, text="Username: ")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

# Create password label and entry
destination_label = tk.Label(root, text="destination: ")
destination_label.pack()
destination_entry = tk.Entry(root)
destination_entry.pack()

# Create password label and entry
weight_label = tk.Label(root, text="weight: ")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
