# %%
import pandas as pd
def display_dataset_info(df):
    print("\nThe first seven rows:")
    print(df.head(7))
    print("\nThe first three columns")
    print(df.iloc[:,:3].head(7))
    print("\nOne row and One header:")
    print(df.head(1))

try:
    apps_df = pd.read_csv(r'C:\Users\amodu\Desktop\J.amoduCOS102\week_8\project-1\Top-Apps-in-Google-Play.csv')
    crypto_df = pd.read_csv(r'C:\Users\amodu\Desktop\J.amoduCOS102\week_8\project-1\Cryptocurrency_Predict_Artificial_Intelligence_V3.csv')
    programming_df = pd.read_csv(r'C:\Users\amodu\Desktop\J.amoduCOS102\week_8\project-1\Programming_Languages_Trend_Over_Time.csv')
    print("Top Apps in Google Play Dataset Information:")
    display_dataset_info(apps_df)
    print("\n-------------------------------------------------------\n")
    print("Cryptocurrency Predict Artificial Intelligence V3 Dataset Information:")
    display_dataset_info(crypto_df)
    print("\n-------------------------------------------------------\n")
    print("Programming Languages Trend Over Time Dataset Information:")
    display_dataset_info(programming_df)
except FileNotFoundError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An error has occurred: {e}")
# Out:
# Top Apps in Google Play Dataset Information:
#
# The first seven rows:
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# 6           7                             Gmail
#
#                                     App Id                 Category  \
# 0                   com.google.android.gms                    Tools
# 1               com.google.android.youtube  Video Players & Editors
# 2  com.google.android.googlequicksearchbox                    Tools
# 3             com.google.android.apps.maps           Travel & Local
# 4                   com.google.android.tts                    Tools
# 5                       com.android.chrome            Communication
# ...
